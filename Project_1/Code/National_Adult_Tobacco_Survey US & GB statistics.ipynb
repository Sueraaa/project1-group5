# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import numpy as np

# %%
# Store filepath in a variable
file = Path("../Resources/National_Adult_Tobacco_Survey__NATS__.csv")

# %%
# Read our data file with the Pandas library
tobacco_servey_df = pd.read_csv(file)
pd.set_option('display.max_columns', None)
tobacco_servey_df
# Out:
#           Year LocationAbbr              LocationDesc  \
# 0    2013-2014           US  National (States and DC)
# 1    2013-2014           US  National (States and DC)
# 2    2013-2014           US  National (States and DC)
# 3    2013-2014           US  National (States and DC)
# 4    2013-2014           US  National (States and DC)
# ..         ...          ...                       ...
# 128  2013-2014           US  National (States and DC)
# 129  2013-2014           US  National (States and DC)
# 130  2013-2014           US  National (States and DC)
# 131  2013-2014           US  National (States and DC)
# 132  2013-2014           US  National (States and DC)
#
#                      TopicType                       TopicDesc  \
# 0    Tobacco Use – Survey Data        Any Tobacco Use (Adults)
# 1    Tobacco Use – Survey Data          Cigarette Use (Adults)
# 2    Tobacco Use – Survey Data              Cigar Use (Adults)
# ...

# %%
#Identifying all the columns
tobacco_servey_df.columns
# Out:
# Index(['Year', 'LocationAbbr', 'LocationDesc', 'TopicType', 'TopicDesc',
#        'MeasureDesc', 'DataSource', 'Response', 'Data_Value_Unit',
#        'Data_Value_Type', 'Data_Value', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Data_Value_Std_Err', 'Low_Confidence_Limit',
#        'High_Confidence_Limit', 'Sample_Size', 'Gender', 'Race', 'Age',
#        'Education', 'GeoLocation', 'TopicTypeId', 'TopicId', 'MeasureId',
#        'StratificationID1', 'StratificationID2', 'StratificationID3',
#        'StratificationID4', 'SubMeasureID'],
#       dtype='object')

# %%
# Get unique values from the 'TopicDesc' column
tobacco_servey_df['TopicDesc'].unique()
# Out:
# array(['Any Tobacco Use (Adults)', 'Cigarette Use (Adults)',
#        'Cigar Use (Adults)', 'Pipe Use (Adults)', 'Hookah Use (Adults)',
#        'E-Cigarette Use (Adults)', 'Smokeless Tobacco Use (Adults)'],
#       dtype=object)

# %%
# Reorganising the columns using double brackets
organised_df = tobacco_servey_df[["Year", "TopicId","TopicDesc","MeasureDesc", "Data_Value", "Data_Value_Std_Err","Low_Confidence_Limit","High_Confidence_Limit","Gender","Age", "Education", "Race"]]
organised_df
# Out:
#           Year TopicId                       TopicDesc     MeasureDesc  \
# 0    2013-2014  160BEH        Any Tobacco Use (Adults)     User Status
# 1    2013-2014  100BEH          Cigarette Use (Adults)  Smoking Status
# 2    2013-2014  103BEH              Cigar Use (Adults)  Smoking Status
# 3    2013-2014  104BEH               Pipe Use (Adults)  Smoking Status
# 4    2013-2014  162BEH             Hookah Use (Adults)  Smoking Status
# ..         ...     ...                             ...             ...
# 128  2013-2014  150BEH  Smokeless Tobacco Use (Adults)     User Status
# 129  2013-2014  150BEH  Smokeless Tobacco Use (Adults)     User Status
# 130  2013-2014  150BEH  Smokeless Tobacco Use (Adults)     User Status
# 131  2013-2014  150BEH  Smokeless Tobacco Use (Adults)     User Status
# 132  2013-2014  150BEH  Smokeless Tobacco Use (Adults)     User Status
#
#      Data_Value  Data_Value_Std_Err  Low_Confidence_Limit  \
# ...

# %%
# Rename Columns
renamed_df = organised_df.rename(columns={"TopicDesc":"Topic Description", "MeasureDesc":"User Description", "Data_Value":"Data Value in %",
                                          "Data_Value_Std_Err": "Data Value Standard Error","Low_Confidence_Limit" : "Lower Confidence Limit",
                                          "High_Confidence_Limit": "Higher Confidence Limit", "TopicId": "Topic ID"})
                                          
renamed_df.head()
# Out:
#         Year Topic ID         Topic Description User Description  \
# 0  2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 1  2013-2014   100BEH    Cigarette Use (Adults)   Smoking Status
# 2  2013-2014   103BEH        Cigar Use (Adults)   Smoking Status
# 3  2013-2014   104BEH         Pipe Use (Adults)   Smoking Status
# 4  2013-2014   162BEH       Hookah Use (Adults)   Smoking Status
#
#    Data Value in %  Data Value Standard Error  Lower Confidence Limit  \
# 0             21.3                        0.2                    20.8
# 1             17.0                        0.2                    16.6
# 2              1.8                        0.1                     1.6
# 3              0.3                        0.0                     0.2
# 4              0.6                        0.0                     0.5
#
#    Higher Confidence Limit   Gender       Age   Education       Race
# 0                     21.7  Overall  All Ages  All Grades  All Races
# ...

# %%
# Identify incomplete rows
renamed_df.count()
# Out:
# Year                         133
# Topic ID                     133
# Topic Description            133
# User Description             133
# Data Value in %              104
# Data Value Standard Error    104
# Lower Confidence Limit       104
# Higher Confidence Limit      104
# Gender                       133
# Age                          133
# Education                    133
# Race                         133
# dtype: int64

# %%
# Drop all rows with missing information
renamed_df = renamed_df.dropna(how='any')

# %%
# Verify dropped rows
renamed_df.count()
# Out:
# Year                         104
# Topic ID                     104
# Topic Description            104
# User Description             104
# Data Value in %              104
# Data Value Standard Error    104
# Lower Confidence Limit       104
# Higher Confidence Limit      104
# Gender                       104
# Age                          104
# Education                    104
# Race                         104
# dtype: int64

# %%
renamed_df
# Out:
#           Year Topic ID               Topic Description User Description  \
# 0    2013-2014   160BEH        Any Tobacco Use (Adults)      User Status
# 1    2013-2014   100BEH          Cigarette Use (Adults)   Smoking Status
# 2    2013-2014   103BEH              Cigar Use (Adults)   Smoking Status
# 3    2013-2014   104BEH               Pipe Use (Adults)   Smoking Status
# 4    2013-2014   162BEH             Hookah Use (Adults)   Smoking Status
# ..         ...      ...                             ...              ...
# 128  2013-2014   150BEH  Smokeless Tobacco Use (Adults)      User Status
# 129  2013-2014   150BEH  Smokeless Tobacco Use (Adults)      User Status
# 130  2013-2014   150BEH  Smokeless Tobacco Use (Adults)      User Status
# 131  2013-2014   150BEH  Smokeless Tobacco Use (Adults)      User Status
# 132  2013-2014   150BEH  Smokeless Tobacco Use (Adults)      User Status
#
#      Data Value in %  Data Value Standard Error  Lower Confidence Limit  \
# ...

# %%
# using loc fuction get data related to e-cig use
e_cigratte_data = renamed_df.loc[renamed_df["Topic Description"] == "E-Cigarette Use (Adults)", :]
e_cigratte_data
# Out:
#           Year Topic ID         Topic Description User Description  \
# 5    2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# 17   2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# 18   2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# 41   2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# 42   2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# 43   2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# 44   2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# 74   2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# 75   2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# 77   2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# 78   2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# 119  2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# 120  2013-2014   161BEH  E-Cigarette Use (Adults)      User Status
# ...

# %%
# using loc fuction get data related to any type of tobaco use
any_tobaco_use_data = renamed_df.loc[renamed_df["Topic Description"] == "Any Tobacco Use (Adults)", :]
any_tobaco_use_data
# Out:
#          Year Topic ID         Topic Description User Description  \
# 0   2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 7   2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 8   2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 21  2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 22  2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 23  2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 24  2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 49  2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 50  2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 51  2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 52  2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 53  2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# 84  2013-2014   160BEH  Any Tobacco Use (Adults)      User Status
# ...

# %%
# using loc fuction get data related to pipe use
pipe_use_data = renamed_df.loc[renamed_df["Topic Description"] == "Pipe Use (Adults)", :]
pipe_use_data
# Out:
#           Year Topic ID  Topic Description User Description  Data Value in %  \
# 3    2013-2014   104BEH  Pipe Use (Adults)   Smoking Status              0.3
# 13   2013-2014   104BEH  Pipe Use (Adults)   Smoking Status              0.6
# 35   2013-2014   104BEH  Pipe Use (Adults)   Smoking Status              0.3
# 36   2013-2014   104BEH  Pipe Use (Adults)   Smoking Status              0.3
# 64   2013-2014   104BEH  Pipe Use (Adults)   Smoking Status              0.3
# 107  2013-2014   104BEH  Pipe Use (Adults)   Smoking Status              0.5
#
#      Data Value Standard Error  Lower Confidence Limit  \
# 3                          0.0                     0.2
# 13                         0.1                     0.5
# 35                         0.0                     0.2
# 36                         0.1                     0.2
# 64                         0.0                     0.2
# 107                        0.1                     0.3
#
# ...

# %%
# using loc fuction get data related to Hookah use
hookaah_use_data = renamed_df.loc[renamed_df["Topic Description"] == "Hookah Use (Adults)", :]
hookaah_use_data
# Out:
#           Year Topic ID    Topic Description User Description  \
# 4    2013-2014   162BEH  Hookah Use (Adults)   Smoking Status
# 15   2013-2014   162BEH  Hookah Use (Adults)   Smoking Status
# 16   2013-2014   162BEH  Hookah Use (Adults)   Smoking Status
# 37   2013-2014   162BEH  Hookah Use (Adults)   Smoking Status
# 38   2013-2014   162BEH  Hookah Use (Adults)   Smoking Status
# 69   2013-2014   162BEH  Hookah Use (Adults)   Smoking Status
# 72   2013-2014   162BEH  Hookah Use (Adults)   Smoking Status
# 114  2013-2014   162BEH  Hookah Use (Adults)   Smoking Status
#
#      Data Value in %  Data Value Standard Error  Lower Confidence Limit  \
# 4                0.6                        0.0                     0.5
# 15               0.8                        0.1                     0.6
# 16               0.4                        0.1                     0.3
# 37               3.2                        0.3                     2.5
# ...

# %%
# using loc fuction get data related to Cigratte use
cigarette_use_data = renamed_df.loc[renamed_df["Topic Description"] == "Cigarette Use (Adults)", :]
cigarette_use_data
# Out:
#          Year Topic ID       Topic Description User Description  \
# 1   2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 9   2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 10  2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 25  2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 26  2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 27  2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 28  2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 54  2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 55  2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 56  2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 57  2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 58  2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 91  2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# 92  2013-2014   100BEH  Cigarette Use (Adults)   Smoking Status
# ...

# %%
## All data groups in a bar chart
# Count the number of occurances for each topic
total_counts = renamed_df['Topic Description'].value_counts()

# Create a list of colors (you can customize this)
colors = ['blue', 'green', 'red', 'orange', 'purple']

# Create a larger figure
plt.figure(figsize=(12, 8))
           
# Create a bar plot
total_counts.plot(kind='bar', color=colors)

# Add labels and save image
plt.title('Adult Tobacco Usage according to the type in United States')
plt.xlabel('Type of Tobacco')
plt.ylabel('Data Value in %')
plt.savefig("../Output_Files/Adult Tobacco Usage according to the type in United States.png", bbox_inches='tight')
plt.show()
print("datasource: National Adult Tobacco Survey (NATS)")
# Out:
# datasource: National Adult Tobacco Survey (NATS)

# %%
# Calculate the mean data value for each topic
average_data_value = renamed_df.groupby('Topic Description')['Data Value in %'].mean()

# Create a list of colors (you can customize this)
colors = ['blue', 'green', 'red', 'orange', 'purple']

# Create a larger figure
plt.figure(figsize=(12, 8))
           
# Create a bar plot
average_data_value.plot(kind='bar', color=colors)

# Add labels and save image
plt.title('Average Adult Tobacco Usage according to the type in United States')
plt.xlabel('Type of Tobacco')
plt.ylabel('Average Data Value in %')
plt.savefig("../Output_Files/Average Adult Tobacco Usage according to the type in United States.png", bbox_inches='tight')
plt.show()
print("datasource: National Adult Tobacco Survey (NATS)")
# Out:
# datasource: National Adult Tobacco Survey (NATS)

# %%
## All data grops in a pie chart
# Create a pie chart
plt.figure(figsize=(8, 8))
colours = ["orange","green","lightblue","yellow","red","purple","pink"]

# Plotting the pie chart
total_counts.plot(kind='pie', autopct='%1.1f%%', shadow=True, startangle=140, colors=colours)

# Add a title
plt.title('Adult Tobacco Usage according to the type in United States')

# Show the pie chart and save
plt.savefig("../Output_Files/Adult Tobacco Usage according to the type in United States(pie-chart).png", bbox_inches='tight')
plt.show()
print("datasource: National Adult Tobacco Survey (NATS)")
# Out:
# datasource: National Adult Tobacco Survey (NATS)

# %%
## According to the education level
# Count the number of occurances for each topic
education_counts = renamed_df['Education'].value_counts()

# Create a list of colors 
colors = ['blue', 'green', 'red', 'orange', 'purple']

# Create a larger figure
plt.figure(figsize=(12, 8))

# Create a bar plot
education_counts.plot(kind='bar', color=colors)

# Add labels and save the plot
plt.title('Tobacco Usage According to the Education Level in United States')
plt.xlabel('Education')
plt.ylabel('Data Value %')
plt.savefig("../Output_Files/Tobacco Usage According to the Education Level in United States.png", bbox_inches='tight')
plt.show()
print("datasource: National Adult Tobacco Survey (NATS)")
# Out:
# datasource: National Adult Tobacco Survey (NATS)

# %%
## According to Race
# Count the number of occurances for each topic
education_counts = renamed_df['Race'].value_counts()

# Create a list of colors 
colors = ['blue', 'green', 'red', 'orange', 'purple']

# Create a bar plot
education_counts.plot(kind='bar', color=colors)

# Add labels
plt.title('Tobacco Usage According to the Race in United States')
plt.xlabel('Race')
plt.ylabel('Data Value in %')
plt.show()
print("datasource: National Adult Tobacco Survey (NATS)")
# Out:
# datasource: National Adult Tobacco Survey (NATS)

# %%
## E-cig use according to the age
# Count occurrences of each gender
gender_counts = e_cigratte_data['Age'].value_counts()

# Create a pie chart
plt.figure(figsize=(10, 8)) 

# Plotting the pie chart
gender_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140,shadow=True, colors=colours)

# Add a title
plt.title('Age Distribution in E-Cigarette Use in United States')

# Show the pie chart and save image
plt.savefig("../Output_Files/Age Distribution in E-Cigarette Use in United States.png", bbox_inches='tight')
plt.show()
print("datasource: National Adult Tobacco Survey (NATS)")
# Out:
# datasource: National Adult Tobacco Survey (NATS)

# %%
e_cigratte_data['Age'].unique()
# Out:
# array(['All Ages', '18 to 24 Years', '25 to 44 Years', '45 to 64 Years',
#        '65 Years and Older'], dtype=object)

# %%
# Get unique values from the 'TopicDesc' column
tobacco_servey_df['TopicDesc'].unique()
# Out:
# array(['Any Tobacco Use (Adults)', 'Cigarette Use (Adults)',
#        'Cigar Use (Adults)', 'Pipe Use (Adults)', 'Hookah Use (Adults)',
#        'E-Cigarette Use (Adults)', 'Smokeless Tobacco Use (Adults)'],
#       dtype=object)

# %%
# Group by 'Topic description'
topic_description = renamed_df.groupby('Topic Description')['Data Value in %']

# Calculate mean, median, variance, standard deviation, and SEM
summary_stats_df = pd.DataFrame({
    'Mean Data Value': drug_region.mean(),
    'Median Data Value': drug_region.median(),
    'Data Value Variance': drug_region.var(),
    'Data Value Std. Dev.': drug_region.std(),
    'Data Value Std. Err.': drug_region.sem()
})
summary_stats_df
# Out:
#                                 Mean Data Value  Median Data Value  \
# Topic Description
# Any Tobacco Use (Adults)              22.294737               21.6
# Cigar Use (Adults)                     1.852941                1.8
# Cigarette Use (Adults)                18.047368               17.3
# E-Cigarette Use (Adults)               3.527778                3.5
# Hookah Use (Adults)                    0.987500                0.7
# Pipe Use (Adults)                      0.383333                0.3
# Smokeless Tobacco Use (Adults)         2.411765                2.4
#
#                                 Data Value Variance  Data Value Std. Dev.  \
# Topic Description
# Any Tobacco Use (Adults)                  96.831637              9.840307
# Cigar Use (Adults)                         0.637647              0.798528
# Cigarette Use (Adults)                    78.952632              8.885529
# E-Cigarette Use (Adults)                   3.012712              1.735717
# ...

# %%
# Create a bar chart for the mean data values
summary_stats_df['Mean Data Value'].plot(kind='bar', color=colors)

# Add labels and title
plt.title('Average Adult Tobacco Usage according to the type in United States')
plt.xlabel('Types of Tobacco')
plt.ylabel('Mean Data Value')

# Show the plot
plt.show()

# %%
## Box plot that shows the distrubution of the data volume for each topic.
# Define selected topics
selected_topics = ['E-Cigarette Use (Adults)', 'Any Tobacco Use (Adults)', 'Cigarette Use (Adults)']

# Filter the DataFrame for the selected topics
selected_df = renamed_df[renamed_df['Topic Description'].isin(selected_topics)]

# Create a box plot with outlier marker face color set to red
plt.figure(figsize=(10, 6)) 
plt.boxplot([selected_df[selected_df['Topic Description'] == topics]['Data Value in %'] for topics in selected_topics], 
            labels=selected_topics, 
            flierprops=dict(markerfacecolor='red'))

# Add labels and title
plt.ylabel('Data Value in %')
plt.xlabel('Type of Tobacco')
plt.title('Distribution of Tobacco Use for Selected Types of Tobacco in US')

# Show the box plot
plt.savefig("../Output_Files/Distribution of Tobacco Use for Selected Types of Tobacco in US.png", bbox_inches='tight')
plt.show()
print("datasource: National Adult Tobacco Survey (NATS)")
# Out:
# datasource: National Adult Tobacco Survey (NATS)

# %%
#reading e_cig and cig data set 
path = "../Resources/Daily_use_ecig.csv" 
data = pd.read_csv(path)  
path = "../Resources/cig_smoking_UK.csv"
dataC=pd.read_csv(path)  
df1 = dataC 
df = data

# %%
#plotting e-cigarette vs cig use  

plt.plot(df['Year'],df['All persons \naged \n16 and over'], color = 'r', label ='All Persons aged 16 and above')
plt.plot(df['Year'], df1['All persons \naged \n16 and over'], label = 'cig users aged 16 and above')
plt.title('E-cigarette and cigarette users in Great Britian') 
plt.xlabel('Year') 
plt.ylabel('E-cigarette users (%)')  
plt.legend()
plt.savefig("../Output_Files/E_cig_vs_cig_users.png", bbox_inches='tight')
plt.show()

# %%
#plotting e-cig vs cig users among males in the UK 
plt.plot(df['Year'],df['Men \naged \n16 and over'],label='e-cigarette users')  
plt.plot(df['Year'],df1['Men \naged \n16 and over'], label='cigarette users') 
plt.title('Male E-cigarette and cigarette users in Great Britian') 
plt.xlabel('Year') 
plt.ylabel('Male UK population (%)')  
plt.legend() 
plt.savefig("../Output_Files/Male_ecig_vs_cig.png", bbox_inches='tight')
plt.show()

# %%
#plotting e-cig vs cig users among the UK population aged 16-24 
plt.plot(df['Year'],df['All persons \naged \n16 to 24'], label = 'e-cigarette users') 
plt.plot(df['Year'],df1['All persons \naged \n16 to 24'], label='cigarette users') 
plt.title('cigarette vs e-cigarette users among persons aged 16-24') 
plt.xlabel('Year') 
plt.ylabel('UK population aged 16-24 (%)')  
plt.legend() 
plt.savefig("../Output_Files/16_24_ecig_vs_cig.png", bbox_inches='tight')
plt.show()

# %%
#plotting e-cig vs cig users among UK population aged 25-34 
plt.plot(df['Year'],df['All persons \naged \n25 to 34'], label = 'e-cigarette users') 
plt.plot(df['Year'],df1['All persons \naged \n25 to 34'], label='cigarette users') 
plt.title('cigarette vs e-cigarette users among persons aged 25-34') 
plt.xlabel('Year') 
plt.ylabel('UK population aged 25-34 (%)')  
plt.savefig("../Output_Files/25_34_ecig_vs_cig.png", bbox_inches='tight')
plt.legend()
plt.show()

# %%
#plotting e-cig vs cig users among UK population aged 35-49 
plt.plot(df['Year'],df['All persons \naged \n35 to 49'], label = 'e-cigarette users') 
plt.plot(df['Year'],df1['All persons \naged \n35 to 49'], label='cigarette users') 
plt.title('cigarette vs e-cigarette users among persons aged 35-49') 
plt.xlabel('Year') 
plt.ylabel('UK population aged 35-49 (%)')  
plt.legend() 
plt.savefig("../Output_Files/35_49_ecig_vs_cig.png", bbox_inches='tight')
plt.show()

# %%
#plotting e-cig vs cig use among Females in the United Kingdom 
plt.plot(df['Year'],df['Women \naged \n16 and over'], label ='e-cigarette users') 
plt.plot(df['Year'],df1['Women \naged \n16 and over'], label ='cigarette users') 
plt.title('cigarette vs e-cigarette users among Females in the United Kingdom') 
plt.xlabel('Year') 
plt.ylabel('Female UK population (%)')  
plt.legend() 
plt.savefig("../Output_Files/Female_ecig_cig.png", bbox_inches='tight')
plt.show()

# %%
#plotting e-cig use with male and female split
plt.plot(df['Year'],df['Men \naged \n16 and over'],label='Men aged 16 years and above') 
plt.plot(df['Year'],df['Women \naged \n16 and over'], label ='Women aged 16 years and above') 
plt.title('Male and Female E-cigarette users in Great Britian') 
plt.xlabel('Year') 
plt.ylabel('E-cigarette users (%)')  
plt.legend() 
plt.savefig("../Output_Files/Male_female_ecig.png", bbox_inches='tight')
plt.show()

# %%
#plotting e-cig user by age split 
df= data[['Year', 'All persons \naged \n16 to 24','All persons \naged \n25 to 34',
       'All persons \naged \n35 to 49', 'All persons \naged \n50 to 59',
       'All persons \naged \n60 and over']]  
plt.figure(figsize = (15,12))
plt.plot(df['Year'],df['All persons \naged \n16 to 24'], label ='Persons aged 16-24') 
plt.plot(df['Year'],df['All persons \naged \n25 to 34'], label = 'Persons aged 25-34') 
plt.plot(df['Year'], df['All persons \naged \n35 to 49'],label = 'Persons aged 35-49') 
plt.plot(df['Year'], df['All persons \naged \n50 to 59'], label = 'Persons aged 50-59') 
plt.plot(df['Year'], df['All persons \naged \n60 and over'], label = 'Persons aged 60 and above')
plt.title('E-cigarette users based on age') 
plt.xlabel('Year') 
plt.ylabel('e-cigeratte users (%)')  
plt.legend() 
plt.savefig("../Output_Files/age_ecig.png", bbox_inches='tight')
plt.show()
