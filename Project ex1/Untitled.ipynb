# %%
# Dependencies
import requests
import json
from config import api_key

# %%
type(api_key)
# Out:
# str

# %%
# URL for GET requests to retrieve vehicle data
response = requests.get("https://ghoapi.azureedge.net/api/Indicator")

# %%
response = response.json()
response
# Out:
# {'@odata.context': 'https://ghoapi.azureedge.net/api/$metadata#Indicator',
#  'value': [{'IndicatorCode': 'AIR_1',
#    'IndicatorName': 'Ambient air pollution attributable deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_11',
#    'IndicatorName': 'Household air pollution attributable deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_13',
#    'IndicatorName': "Household air pollution attributable deaths per 100'000 capita",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_14',
#    'IndicatorName': "Household air pollution  attributable deaths per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_17',
#    'IndicatorName': 'Household air pollution attributable DALYs (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_18',
#    'IndicatorName': "Household air pollution  attributable DALYs per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_4',
#    'IndicatorName': 'Ambient air pollution attributable deaths in children under 5 years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_50',
#    'IndicatorName': 'Ambient air pollution attributable deaths (per 100 000 population, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_51',
#    'IndicatorName': 'Household air pollution attributable death rate (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_52',
#    'IndicatorName': 'Household air pollution attributable death rate (per 100 000 population, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_63',
#    'IndicatorName': "Household and ambient air pollution attributable DALYs in children under 5 years ('000)",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_9',
#    'IndicatorName': 'Ambient air pollution attributable DALYs  (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMR_GI_001',
#    'IndicatorName': 'Status of countries enrolled in GLASS',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_COORD01',
#    'IndicatorName': 'Functioning national AMR surveillance plan',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_2_1',
#    'IndicatorName': 'Ambient air pollution in urban areas (Annual PM<sub>10</sub> [&#956;g/m<sup>3</sup>])',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_3_1',
#    'IndicatorName': 'Percent of urban inhabitants living in cities covered by PM measurements',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_39',
#    'IndicatorName': 'Household air pollution attributable DALYs (per 100 000, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_41',
#    'IndicatorName': 'Ambient air pollution attributable deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_43',
#    'IndicatorName': 'Ambient air pollution attributable DALYs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_44',
#    'IndicatorName': 'DALYs attributable to ambient air pollution (age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_61',
#    'IndicatorName': 'Household and ambient air pollution attributable DALYs (per 100 000 capita)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_8',
#    'IndicatorName': 'Ambient air pollution attributable DALYs  in children under 5 years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_90',
#    'IndicatorName': 'Ambient air pollution attributable DALYs  (per 100 000 population, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMR_GI_002',
#    'IndicatorName': 'Status of National coordination center establishment',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMR_GI_003',
#    'IndicatorName': 'Status of National plans to implement and strengthen antimicrobial surveillance',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_COORD03',
#    'IndicatorName': 'Nomination of National Focal Point (NFP)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_QA03',
#    'IndicatorName': 'EQA provided to local laboratories participating in GLASS',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_SURVL02',
#    'IndicatorName': 'Number of National surveillance sites in each country providing data to GLASS: outpatient facility category',
#    'Language': 'EN'},
#   {'IndicatorCode': 'asfr1',
#    'IndicatorName': 'Adolescent fertility rate (per 1000 women aged 15-19 years)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'ASSISTIVETECH_METNEED',
#    'IndicatorName': 'Prevalence of met need of assistive products (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_airtime',
#    'IndicatorName': 'Process evaluation was employed to assess implementation',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_media_planning',
#    'IndicatorName': 'Campaign utilized media planning',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_news',
#    'IndicatorName': 'Earned media/public relations were used to promote the campaign',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_tv_radio',
#    'IndicatorName': 'Campaign aired on television and/or radio',
#    'Language': 'EN'},
#   {'IndicatorCode': 'carep',
#    'IndicatorName': 'Children aged < 5 years with pneumonia symptoms taken to a health facility (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CaseCS',
#    'IndicatorName': 'Congenital syphilis number of cases, reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_3',
#    'IndicatorName': "Climate change attributable deaths per 100'000 capita",
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_5',
#    'IndicatorName': "Climate change attributable deaths ('000) in children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_6',
#    'IndicatorName': "Climate change  attributable deaths per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_7',
#    'IndicatorName': 'Ambient air pollution attributable DALYs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_COORD02',
#    'IndicatorName': 'Establishment of National Coordination Centre (NCC)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_COORD04',
#    'IndicatorName': 'Establishment of national reference laboratory (NRL)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_QA01',
#    'IndicatorName': 'EQA provided to the national reference laboratory (NRL)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q3x4_1',
#    'IndicatorName': 'Existence of legislation for advanced care directives for people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x1x2',
#    'IndicatorName': 'Existence of approved government dementia standards/ guidelines/ protocols',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_SURVL03',
#    'IndicatorName': 'Number of local clinical laboratories in each country performing AST to support national AMR surveillance sites',
#    'Language': 'EN'},
#   {'IndicatorCode': 'anc1',
#    'IndicatorName': 'Antenatal care coverage - at least one visit (in the two or three years preceding the survey) (%',
#    'Language': 'EN'},
#   {'IndicatorCode': 'anc15',
#    'IndicatorName': 'Antenatal care coverage - at least one visit (in the five years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'anc4',
#    'IndicatorName': 'Antenatal care coverage - at least four visits (in the two or three years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x2_3',
#    'IndicatorName': 'Existence of standards/ guidelines/ protocols for management of dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x3x4_3',
#    'IndicatorName': 'Existence of standards/ guidelines/ protocols of care in nursing & residential care facilities for people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CCO_2',
#    'IndicatorName': 'Human development index rank',
#    'Language': 'EN'},
#   {'IndicatorCode': 'bcgv',
#    'IndicatorName': 'BCG immunization coverage among one-year-olds (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'BP_03',
#    'IndicatorName': 'Raised blood pressure (SBP>=140 OR DBP>=90) (crude estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_QA04',
#    'IndicatorName': 'GLASS pathogens testing covered by EQA',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_QA05',
#    'IndicatorName': 'Types of AST standards followed by countries',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_SURVL01',
#    'IndicatorName': 'Number of national surveillance sites in each country providing data to GLASS: hospital category',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHILDMORT5TO14',
#    'IndicatorName': 'Mortality rate for 5-14 year-olds (probability of dying per 1000 children aged 5-14 years)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHOLERA_0000000001',
#    'IndicatorName': 'Number of reported cases of cholera',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CM_01',
#    'IndicatorName': 'Number of under-five deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CM_02',
#    'IndicatorName': 'Number of infant deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'BP_04',
#    'IndicatorName': 'Raised blood pressure (SBP>=140 OR DBP>=90) (age-standardized estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_aud_research',
#    'IndicatorName': 'Formative research was conducted',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_gov_prog',
#    'IndicatorName': 'Campaign was part of a comprehensive tobacco control programme',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_mat_tested',
#    'IndicatorName': 'Campaign was pre-tested',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_7',
#    'IndicatorName': "Climate change attributable DALYs ('000) in children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'cci',
#    'IndicatorName': 'Composite coverage index (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CCO_3',
#    'IndicatorName': 'Gender inequality index rank',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES07',
#    'IndicatorName': 'Types of lists recommending health technology for high burden diseases',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES20',
#    'IndicatorName': 'Availability of technical specifications of medical devices to support procurement or donations',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES21',
#    'IndicatorName': 'Total density per million population: Telecobalt Unit',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES22',
#    'IndicatorName': 'Total density per million population: Radiotherapy units',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E_Group',
#    'IndicatorName': 'Enforcing bans on tobacco advertising, promotion and sponsorship',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E10_compliance',
#    'IndicatorName': 'Compliance of ban on promotional discounts',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E13_brand_placement',
#    'IndicatorName': 'Ban on appearance of tobacco brands in TV and/or films (product placement)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q3x4_3',
#    'IndicatorName': 'Existence of legislation to end discrimination against carers of people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x2_1',
#    'IndicatorName': 'Existence of standards/ guidelines/ protocols for prevention and risk reduction of dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CATARACTSURGICALEFFECTIVE',
#    'IndicatorName': 'Effective cataract surgical coverage of adults aged 50 and over (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_1',
#    'IndicatorName': 'Climate change attributable deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_4',
#    'IndicatorName': "Climate change attributable DALYs per 100'000 capita",
#    'Language': 'EN'},
#   {'IndicatorCode': 'cci2030',
#    'IndicatorName': 'Composite coverage index (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x2_5',
#    'IndicatorName': 'Existence of standards/ guidelines/ protocols for treatment and support of carers and families of people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHOLERA_0000000002',
#    'IndicatorName': 'Number of reported deaths from cholera',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_15',
#    'IndicatorName': 'Household air pollution attributable DALYs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_2',
#    'IndicatorName': 'Ambient air pollution (Annual PM10 [ug/m3])',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_45',
#    'IndicatorName': 'Ambient air pollution attributable YLLs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q3x3a_2',
#    'IndicatorName': 'Existence of legislation to file appeals protecting the rights of people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q3x3a_4',
#    'IndicatorName': 'Existence of legislation to promote monitoring of human rights conditions of people with dementia in facilities where they reside',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q3x3b_1',
#    'IndicatorName': 'Existence of legislation to end coercieve practices for people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q3x4_2',
#    'IndicatorName': 'Existence of legislation to end discrimination against people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x1',
#    'IndicatorName': 'Existence of dementia standards/ guidelines/ protocols',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x1x1_SQ001',
#    'IndicatorName': 'Implementation level of dementia standards/ guidelines/ protocols (National)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'cpmt',
#    'IndicatorName': 'Contraceptive prevalence - modern and traditional methods (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'csection',
#    'IndicatorName': 'Births by caesarean section (in the two or three years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES00',
#    'IndicatorName': 'Total density per 100 000 population: Hospitals',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES05',
#    'IndicatorName': 'Total density per 100 000 population: Specialized hospitals',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x3x4_2',
#    'IndicatorName': 'Existence of standards/ guidelines/ protocols for palliative and end-of-life care for people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x1',
#    'IndicatorName': 'Availability of mechanisms to coordinate dementia care across sectors',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CCO_WHS9_85',
#    'IndicatorName': 'Literacy rate among adults aged >= 15 years (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CHOLERA_0000000003',
#    'IndicatorName': 'Cholera case fatality rate',
#    'Language': 'EN'},
#   {'IndicatorCode': 'cpmo',
#    'IndicatorName': 'Contraceptive prevalence - modern methods (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES01',
#    'IndicatorName': 'Total density per 100 000 population: Health posts',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES02',
#    'IndicatorName': 'Total density per 100 000 population: Health centres',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES06',
#    'IndicatorName': 'Availability of national standards or recommended lists of medical devices',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES15',
#    'IndicatorName': 'Health technology (medical device) national policy',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES23',
#    'IndicatorName': 'Total density per million females aged from 50 to 69 years old: Mammography units',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E1_compliance',
#    'IndicatorName': 'Compliance of ban on advertising on national TV and radio',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES10',
#    'IndicatorName': 'Total density per million population: Positron Emission tomography',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES13',
#    'IndicatorName': 'Type of nomenclature system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES14',
#    'IndicatorName': 'Use of nomenclature system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES18',
#    'IndicatorName': 'Availability of national list of approved medical devices for procurement or reimbursement',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES19',
#    'IndicatorName': 'National guidelines, policies or recommendations on the procurement of medical devices',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E14a_prod_tv_films',
#    'IndicatorName': 'Ban on appearance of tobacco products in TV and/or films',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E1_nat_tv_radio',
#    'IndicatorName': 'Ban on advertising: National TV and radio',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E10_promo_discounts',
#    'IndicatorName': 'Ban on promotional discounts',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E11_brand_stretching',
#    'IndicatorName': 'Ban on non-tobacco goods AND services identified with tobacco brand names',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E11_compliance',
#    'IndicatorName': 'Compliance of ban on non-tobacco goods AND services identified with tobacco brand names',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E12_brand_sharing',
#    'IndicatorName': 'Ban on brand name of non-tobacco products used for tobacco product',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E12_compliance',
#    'IndicatorName': 'Compliance of ban on brand name of non-tobacco products used for tobacco product',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E13_compliance',
#    'IndicatorName': 'Compliance of ban on appearance of tobacco brands in TV and/or films (product placement)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E15c_sponsor_publicity',
#    'IndicatorName': 'Banning the publicity of financial or other sponsorship or support by the tobacco industry of events, activities, individuals',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E17_csr_promo_others',
#    'IndicatorName': 'Ban on entities other than tobacco companies/tobacco industry publicizing the Corporate Social Responsibility activities of the tobacco companies',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_18C',
#    'IndicatorName': 'Prevalence of underweight among adults, BMI < 18 (crude estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_25C',
#    'IndicatorName': 'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (crude estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_30A',
#    'IndicatorName': 'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (age-standardized estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_PLUS1C',
#    'IndicatorName': 'Prevalence of overweight among children and adolescents, BMI > +1 standard deviations above the median (crude estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA004',
#    'IndicatorName': 'Number of under-five deaths from malaria',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E14_prod_tv_films',
#    'IndicatorName': 'Appearance of tobacco products in TV and/or films',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA003',
#    'IndicatorName': 'Estimated number of malaria deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MCV2',
#    'IndicatorName': 'Measles-containing-vaccine second-dose (MCV2) immunization coverage by the nationally recommended age (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000006_AGE1519',
#    'IndicatorName': 'Unmet need for family planning, among girls aged 15-19 (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000001',
#    'IndicatorName': 'Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000005',
#    'IndicatorName': 'Contraceptive prevalence (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000018',
#    'IndicatorName': 'Deaths due to tuberculosis among HIV-positive people (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000019',
#    'IndicatorName': 'Prevalence of HIV among adults aged >=15 years (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000020',
#    'IndicatorName': 'Incidence of tuberculosis (per 100 000 population per year)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000007',
#    'IndicatorName': 'Under-five mortality rate (probability of dying by age 5 per 1000 live births)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000011',
#    'IndicatorName': 'Median consumer price ratio of selected generic medicines - Public',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000014',
#    'IndicatorName': 'Children aged <5 years with fever who received treatment with any antimalarial (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000016',
#    'IndicatorName': 'Deaths due to malaria (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E14_compliance',
#    'IndicatorName': 'Compliance of ban on appearance of tobacco products in TV and/or films',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E14b_movies_anti_tob_ads',
#    'IndicatorName': 'Requirement to present prescribed anti-tobacco ads before, during or after the broadcasting or showing of any visual entertainment media product that depicts tobacco products, use or images',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E15_compliance',
#    'IndicatorName': 'Compliance of ban on sponsored events',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E15_sponsored_events',
#    'IndicatorName': 'Sponsored events',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E15a_sponsorship',
#    'IndicatorName': 'Complete ban on sponsorship',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E15b_sponsor_contribution',
#    'IndicatorName': 'Ban on any form of contribution (financial or other support) to any event, activity or individual',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA001',
#    'IndicatorName': 'Malaria - number of reported deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000010',
#    'IndicatorName': 'Median availability of selected generic medicines (%) - Public',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000013',
#    'IndicatorName': 'Children aged <5 years sleeping under insecticide-treated nets (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000017',
#    'IndicatorName': 'Deaths due to tuberculosis among HIV-negative people (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_10',
#    'IndicatorName': "Ambient air pollution  attributable DALYs per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_12',
#    'IndicatorName': 'Household air pollution attributable deaths in children under 5 years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_16',
#    'IndicatorName': 'Household air pollution attributable DALYs in children under 5 years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_3',
#    'IndicatorName': "Percentage of the total population living in cities > 100'000 inhabitants",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_35',
#    'IndicatorName': 'Joint effects of air pollution attributable deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_36',
#    'IndicatorName': 'Joint effects of air pollution attributable deaths in children under 5 years',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_42',
#    'IndicatorName': 'Ambient air pollution attributable death rate (per 100 000 population, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_62',
#    'IndicatorName': 'Household and ambient air pollution attributable DALYs (per 100 000 capita, age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AMRGLASS_QA02',
#    'IndicatorName': 'EQA provided for bacterial identification and AST',
#    'Language': 'EN'},
#   {'IndicatorCode': 'anc45',
#    'IndicatorName': 'Antenatal care coverage - at least four visits (in the five years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x3x4_4',
#    'IndicatorName': 'Existence of standards/ guidelines/ protocols of care in hospital for people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x1x1_7',
#    'IndicatorName': 'Identification of different sectors in dementia care coordination (Civil society)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'BP_05',
#    'IndicatorName': 'Mean systolic blood pressure (crude estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'BP_06',
#    'IndicatorName': 'Mean systolic blood pressure (age-standardized estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_eval_impact',
#    'IndicatorName': 'Outcome evaluation was employed to assess effectiveness',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Camp_nat',
#    'IndicatorName': 'At least one national mass media campaign ran during the survey period',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CATARACTSURGICAL',
#    'IndicatorName': 'Cataract surgical coverage of adults aged 50 and over (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_2',
#    'IndicatorName': "Climate change attributable DALYs ('000)",
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x1x2',
#    'IndicatorName': 'Implementation level [national/subnational] of dementia care coordination',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q6x2_3',
#    'IndicatorName': 'Inclusion of basic dementia competencies in training of nurses',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q6x2_6',
#    'IndicatorName': 'Inclusion of basic dementia competencies in training of personal support workers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000022',
#    'IndicatorName': 'Tuberculosis detection rate under DOTS (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000025',
#    'IndicatorName': 'Births attended by skilled health personnel (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x1x1_6',
#    'IndicatorName': 'Identification of different sectors in dementia care coordination (Housing)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q6x1_2',
#    'IndicatorName': 'Number of neurologists (per 100,000)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000023',
#    'IndicatorName': 'Prevalence of tuberculosis (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x1x1_1',
#    'IndicatorName': 'Identification of different sectors in dementia care coordination  (Health)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x1x1_4',
#    'IndicatorName': 'Identification of different sectors in dementia care coordination (Employment)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x2_1',
#    'IndicatorName': 'Availability of diagnostic services in community for dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x2_3',
#    'IndicatorName': 'Availability of psychosocial and rehabilitation services in community for dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x3_2',
#    'IndicatorName': 'Accessibility of behaviour and psychological management in community for dementia [Capital/capital and main cities/capital, main cities, rural areas]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q6x2_4',
#    'IndicatorName': 'Inclusion of basic dementia competencies in training of pharmaceutical personnel',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q6x2_5',
#    'IndicatorName': 'Inclusion of basic dementia competencies in training of social workers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x2_5',
#    'IndicatorName': 'Availability of palliative and end-of-life care services in community for dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x1x1_8',
#    'IndicatorName': 'Identification of different sectors in dementia care coordination (Private sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x1x1_other',
#    'IndicatorName': 'Identification of different sectors in dementia care coordination (Other)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q6x1_3',
#    'IndicatorName': 'Number of geriatricians or psychogeriatricians (per 100,000)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q6x2_2',
#    'IndicatorName': 'Inclusion of basic dementia competencies in training of specialists',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x4_5',
#    'IndicatorName': 'Majority provider of palliative and end-of-life care services in community for dementia [public, private]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x4_6',
#    'IndicatorName': 'Majority provider of social and financial protection for dementia [public, private]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x2_6',
#    'IndicatorName': 'Availability of social and financial protection for dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000034',
#    'IndicatorName': 'Antiretroviral therapy coverage among people with advanced HIV infection (%), WHO 2006 guidelines',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x1',
#    'IndicatorName': 'Existence of community-based health or social care services for dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x2_4',
#    'IndicatorName': 'Availability of activities of daily living support services in community for dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x3_1',
#    'IndicatorName': 'Accessibility of diagnostic services in community for dementia [Capital/capital and main cities/capital, main cities, rural areas]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x5_3',
#    'IndicatorName': 'Estimated number of people receiving psychosocial and rehabilitation services in community for dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000025_AGE1519',
#    'IndicatorName': 'Births attended by skilled health personnel, among girls aged 15-19 (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000027',
#    'IndicatorName': 'Children aged <5 years stunted (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000031',
#    'IndicatorName': 'Smear-positive tuberculosis treatment-success rate (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MH_13',
#    'IndicatorName': 'Beds for mental health in general hospitals (per 100,000)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MH_16',
#    'IndicatorName': 'Beds in mental hospitals (per 100,000)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MH_18',
#    'IndicatorName': 'Mental health units in general hospitals (per 100,000)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MH_22',
#    'IndicatorName': 'Occupational therapists in mental health sector (per 100,000)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MH_3',
#    'IndicatorName': 'Stand-alone mental health legislation',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x3_6',
#    'IndicatorName': 'Accessibility of social and financial protection for dementia [Capital/capital and main cities/capital, main cities, rural areas]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x4_1',
#    'IndicatorName': 'Majority provider of diagnostic services in community for dementia [public, private]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000032',
#    'IndicatorName': 'Maternal mortality ratio (per 100 000 live births) - Country reported estimates',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MENING_3',
#    'IndicatorName': 'Number of meningitis epidemic districts',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MH_1',
#    'IndicatorName': 'Mental health policy',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MH_17',
#    'IndicatorName': 'Mental hospitals (per 100,000)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MH_2',
#    'IndicatorName': 'Mental health plan',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000029',
#    'IndicatorName': 'Prevalence of HIV among adults aged 15 to 49 (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000030',
#    'IndicatorName': 'Smear-positive tuberculosis case-detection rate (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MENING_1',
#    'IndicatorName': 'Number of suspected meningitis deaths reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MENING_2',
#    'IndicatorName': 'Number of suspected meningitis cases reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MH_10',
#    'IndicatorName': 'Mental health outpatient facilities (per 100,000)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MH_11',
#    'IndicatorName': 'Mental health day treatment facilities (per 100,000)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CC_8',
#    'IndicatorName': "Climate change  attributable DALYs per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'CCO_1',
#    'IndicatorName': 'Poverty headcount ratio at $1.25 a day (PPP) (% of population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_46',
#    'IndicatorName': 'YLLs attributable to ambient air pollution (age-standardized)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_5',
#    'IndicatorName': 'Ambient air pollution attributable death rate (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_6',
#    'IndicatorName': "Ambient air pollution  attributable deaths per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'AIR_60',
#    'IndicatorName': "Household and ambient air pollution attributable DALYs ('000)",
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q3x3a_1',
#    'IndicatorName': 'Existence of legislation for supported decision making for people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q3x3a_3',
#    'IndicatorName': 'Existence of legislation to promote community-based services for people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x1x1_SQ002',
#    'IndicatorName': 'Implementation level of dementia standards/ guidelines/ protocols (Sub-national)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x2_2',
#    'IndicatorName': 'Existence of standards/ guidelines/ protocols for diagnosis of dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x2_4',
#    'IndicatorName': 'Existence of standards/ guidelines/ protocols for other post-diagnostic supports of people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'CM_03',
#    'IndicatorName': 'Number of neonatal deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'csection5',
#    'IndicatorName': 'Births by caesarean section (in the five years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES03',
#    'IndicatorName': 'Total density per 100 000 population: District/rural hospitals',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES04',
#    'IndicatorName': 'Total density per 100 000 population: Provincial hospitals',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES08',
#    'IndicatorName': 'Total density per million population: Magnetic Resonance Imaging',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES09',
#    'IndicatorName': 'Total density per million population: Computed tomography units',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES11',
#    'IndicatorName': 'Total density per million population: Gamma camera or Nuclear medicine',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES12',
#    'IndicatorName': 'Total density per million population: Linear Accelerator',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES16',
#    'IndicatorName': 'Unit in the Ministry of Health responsible for the management of medical devices',
#    'Language': 'EN'},
#   {'IndicatorCode': 'DEVICES17',
#    'IndicatorName': 'Procurement of medical devices carried out at the national level',
#    'Language': 'EN'},
#   {'IndicatorCode': 'dptv',
#    'IndicatorName': 'DTP3 immunization coverage among one-year-olds (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q4x3x4_1',
#    'IndicatorName': 'Existence of standards/ guidelines/ protocols for advance care directives, power of attorney or guardianship for people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x1x1_2',
#    'IndicatorName': 'Identification of different sectors in dementia care coordination (Social)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x1x1_3',
#    'IndicatorName': 'Identification of different sectors in dementia care coordination (Education)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x1x1_5',
#    'IndicatorName': 'Identification of different sectors in dementia care coordination (Justice)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x1x3',
#    'IndicatorName': 'Presence of formal agreement/joint plan for dementia care coordination',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q5x2',
#    'IndicatorName': 'Availability of dementia care coordination standards/ guidelines/ protocols',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q6x2_1',
#    'IndicatorName': 'Inclusion of basic dementia competencies in training of physicians',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_MEAN',
#    'IndicatorName': 'Mean BMI (kg/m²) (age-standardized estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_MEANC',
#    'IndicatorName': 'Mean BMI (kg/m&#xb2;) (crude estimate)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_PLUS1A',
#    'IndicatorName': 'Prevalence of overweight among children and adolescents, BMI > +1 standard deviations above the median (age-standardized estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_PLUS2C',
#    'IndicatorName': 'Prevalence of obesity among children and adolescents, BMI > +2 standard deviations above the median (crude estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Aspirin',
#    'IndicatorName': 'General availability of aspirin (100 mg) in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9_6',
#    'IndicatorName': 'Outpatient social centres',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9x2_5',
#    'IndicatorName': 'Estimated percentage of residential long-term care facilities following national dementia standards',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_AlcPlan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan to reduce the harmful use of alcohol',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_BreastCancer',
#    'IndicatorName': 'General availability of breast cancer screening (by palpation or mammogram) at the primary health care level',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Bronchodilators',
#    'IndicatorName': 'General availability of bronchodilators in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_CancerPlan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan for cancer',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_coronary',
#    'IndicatorName': 'General availability of coronary bypass or stenting in the public health system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_25A',
#    'IndicatorName': 'Prevalence of overweight among adults, BMI &GreaterEqual; 25 (age-standardized estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9x4_1',
#    'IndicatorName': 'Density of adult day centres (per 100,000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9x4_3',
#    'IndicatorName': 'Dementia-specific adult day centre places (per 10,000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9x6_2',
#    'IndicatorName': 'Estimated number of people with dementia receiving services at outpatient social centre',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_CCBlkrs',
#    'IndicatorName': 'General availability of CC blockers in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_CervCy',
#    'IndicatorName': 'General availability of cervical cytology at the primary health care level',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_cervicalcancerpgmcvg',
#    'IndicatorName': 'Coverage of national cervical cancer screening program (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_CVDPlan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan for cardiovascular diseases',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9_1',
#    'IndicatorName': 'Dementia care facilities [hospitals]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9_3',
#    'IndicatorName': 'Care facilities [hospice centres]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9_5',
#    'IndicatorName': 'Outpatient health centres',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9x1_3',
#    'IndicatorName': 'Dementia-specific hospital beds (per 10,000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9x1_5',
#    'IndicatorName': 'Total dementia hospital admissions (per 100,000)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9x1_7',
#    'IndicatorName': 'Estimated percentage of hospitals following national dementia standards',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9x2_1',
#    'IndicatorName': 'Density of residential long-term care facilities (per 100,000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_PLUS2A',
#    'IndicatorName': 'Prevalence of obesity among children and adolescents, BMI > +2 standard deviations above the median (age-standardized estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_breastcancerscreening',
#    'IndicatorName': 'Existence of national screening program for breast cancer',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_chemo',
#    'IndicatorName': 'General availability of chemotherapy in the public health system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_CRDPlan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan for chronic respiratory diseases',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_diabtest',
#    'IndicatorName': 'General availability of diabetes testing (by blood glucose measurement, OGTT) at the primary health care level',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_dietpaaware',
#    'IndicatorName': 'Implementation of diet and/or physical activity public awareness program',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9x2_2',
#    'IndicatorName': 'Residential long-term care beds (per 10 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9x3_1',
#    'IndicatorName': 'Density of hospice centres (per 100,000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9x3_2',
#    'IndicatorName': 'Hospice centre beds (per 10 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9x3_3',
#    'IndicatorName': 'Dementia-specific hospice care beds (per 10,000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x3_5',
#    'IndicatorName': 'Accessibility of palliative and end-of-life care services in community for dementia [Capital/capital and main cities/capital, main cities, rural areas]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x4_2',
#    'IndicatorName': 'Majority provider of behaviour and psychological management in community for dementia [public, private]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x4_4',
#    'IndicatorName': 'Majority provider of activities of daily living support services in community for dementia [public, private]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_dialysis',
#    'IndicatorName': 'General availability of dialysis in the public health system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_MultisecComm',
#    'IndicatorName': 'Existence of a national multisectoral commission, agency or mechanism for NCDs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_NCDUnit_Operational',
#    'IndicatorName': 'Existence of an Operational Unit, Branch, or Dept. in Ministry of Health with responsibility for NCDs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_paaware',
#    'IndicatorName': 'Implementation of physical activity public awareness program',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x5_4',
#    'IndicatorName': 'Estimated number of people receiving activities of daily living support services in community for dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q8x5_6',
#    'IndicatorName': 'Estimated number of people with dementia receiving social and financial protection for dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9_2',
#    'IndicatorName': 'Care facilities [long-term care]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q9_4',
#    'IndicatorName': 'Adult day centres',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_cervicalcancermethod',
#    'IndicatorName': 'Most widely used screening method in national cervical cancer screening program',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_cervicalcancerscreening',
#    'IndicatorName': 'Existence of national screening program for cervical cancer',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_CholMsmt',
#    'IndicatorName': 'General availability of total cholesterol measurement at the primary health care level',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_DietPlan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan to reduce unhealthy diet related to NCDs',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_HbA1c',
#    'IndicatorName': 'General availability of diabetes testing (by HbA1c) at the primary health care level',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Insulin',
#    'IndicatorName': 'General availability of insulin in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q7x1_AVAIL',
#    'IndicatorName': 'Availability of dementia diagnostic rate',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E15d_csr_ban',
#    'IndicatorName': 'Ban on Corporate Social Responsibility activities (CSR)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'E18_csr_anti_tobacco_media',
#    'IndicatorName': 'Ban on tobacco companies funding or making contributions (including in-kind contributions) to smoking prevention media campaigns, including those directed at youth',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_18A',
#    'IndicatorName': 'Prevalence of underweight among adults, BMI < 18 (age-standardized estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_30C',
#    'IndicatorName': 'Prevalence of obesity among adults, BMI &GreaterEqual; 30 (crude estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_MINUS2A',
#    'IndicatorName': 'Prevalence of thinness among children and adolescents, BMI < -2 standard deviations below the median (age-standardized estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_hpv',
#    'IndicatorName': 'Existence of national HPV vaccination programme',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_integNCDplan',
#    'IndicatorName': 'Existence of an operational, multisectoral national NCD policy, strategy or action plan that integrates several NCDs and their risk factors',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_BMI_MINUS2C',
#    'IndicatorName': 'Prevalence of thinness among children and adolescents, BMI < -2 standard deviations below the median (crude estimate) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_ACE',
#    'IndicatorName': 'General availability of ACE inhibitors in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Nicotine',
#    'IndicatorName': 'General availability of nicotine replacement therapy in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_oralhealthplan',
#    'IndicatorName': 'Existence of operational policy/strategy/action plan for oral health',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_palliative_prim',
#    'IndicatorName': 'General availability of palliative care in primary health care in the public health system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_photocoag',
#    'IndicatorName': 'General availability of retinal photocoagulation in the public health system',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_betablockers',
#    'IndicatorName': 'General availability of beta blockers in the public health sector',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA002',
#    'IndicatorName': 'Estimated number of malaria cases',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MALARIA005',
#    'IndicatorName': 'Malaria incidence per 100 000 population',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000003',
#    'IndicatorName': 'Adolescent birth rate (per 1000 women aged 15-19 years)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000005_AGE1519',
#    'IndicatorName': 'Contraceptive prevalence, among girls aged 15-19 (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'MDG_0000000015',
#    'IndicatorName': 'Prevalence of condom use by adults during higher-risk sex (15-49) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_rheumreg',
#    'IndicatorName': 'Existence of a register of patients who had rheumatic fever and rheumatic heart disease',
#    'Language': 'EN'},
#   {'IndicatorCode': 'NCD_CCS_Steroid',
# ...
#    'Language': 'EN'},
#   {'IndicatorCode': 'HWWS_2',
#    'IndicatorName': "Handwashing with soap after cleaning child's stool (%)",
#    'Language': 'EN'},
#   {'IndicatorCode': 'IHR02',
#    'IndicatorName': 'Coordination',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IHR06',
#    'IndicatorName': 'Risk communication',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IHR08', 'IndicatorName': 'Laboratory', 'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_5PUB',
#    'IndicatorName': 'Majority provider of information  on financial benefits/social protection for dementia carers (Public sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'HWF_0015',
#    'IndicatorName': 'Pharmacists  (number)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'HWF_0019',
#    'IndicatorName': 'Medical and Pathology Laboratory scientists  (number)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'HWF_0020',
#    'IndicatorName': 'Medical and Pathology Laboratory Technicians  (number)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'HWF_0024',
#    'IndicatorName': 'Community Health Workers (number)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IHR05',
#    'IndicatorName': 'Preparedness',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IR_CARBAMATE_EXTENT',
#    'IndicatorName': 'Percentage of sites for which carbamate resistance was reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x3',
#    'IndicatorName': 'Estimated number of dementia carers receiving training and education',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x2x3',
#    'IndicatorName': 'Estimated number of dementia carers receiving psycho-social supports',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x3x3',
#    'IndicatorName': 'Estimated number of dementia carers receiving respite care',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x4x3',
#    'IndicatorName': 'Estimated number of dementia carers receiving information on legal rights',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q13x1',
#    'IndicatorName': 'Existence of at least one functioning dementia awareness campaign',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q13x1x1',
#    'IndicatorName': 'Implementation level [national/subnational] of dementia awareness campaign',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q13x3',
#    'IndicatorName': 'Existence of at least one functioning risk reduction campaign',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IR_INSECTICIDERESISTANCE_PREV',
#    'IndicatorName': 'Number of insecticide classes to which resistance was reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x5x3',
#    'IndicatorName': 'Estimated number of dementia carers receiving financial benefits/social protection',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q13x3x1',
#    'IndicatorName': 'Implementation level [national/subnational] of dementia risk reduction campaign',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q14x2_1',
#    'IndicatorName': 'Existence of dementia-friendly initiative to improve accessibility of public spaces',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IHR03',
#    'IndicatorName': 'Surveillance',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IHR07',
#    'IndicatorName': 'Human resources',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IHR09',
#    'IndicatorName': 'Points of entry',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IHR12', 'IndicatorName': 'Chemical', 'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x1',
#    'IndicatorName': 'Inclusion of dementia training and education for non-health workers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_1',
#    'IndicatorName': 'Existence of dementia training for volunteers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IHR11', 'IndicatorName': 'Food safety', 'Language': 'EN'},
#   {'IndicatorCode': 'IHR13',
#    'IndicatorName': 'Radionuclear',
#    'Language': 'EN'},
#   {'IndicatorCode': 'imr',
#    'IndicatorName': 'Infant mortality rate (deaths per 1000 live births)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IR_ORGANOCHLORINE_EXTENT',
#    'IndicatorName': 'Percentage of sites for which organochlorine resistance was reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IR_ORGANOPHOSPHATE_EXTENT',
#    'IndicatorName': 'Percentage of sites for which organophosphate resistance was reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IR_ORGANOPHOSPHATE_PRESENCE',
#    'IndicatorName': 'Organophosphate resistance reported for at least one site',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_7',
#    'IndicatorName': 'Existence of dementia training for financial service staff',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_8',
#    'IndicatorName': 'Existence of dementia training for retail and hospitality staff',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IR_ORGANOCHLORINE_PRESENCE',
#    'IndicatorName': 'Organochlorine resistance reported for at least one site',
#    'Language': 'EN'},
#   {'IndicatorCode': 'itnch',
#    'IndicatorName': 'Children aged < 5 years sleeping under insecticide-treated nets (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'itnwm',
#    'IndicatorName': 'Pregnant women sleeping under insecticide-treated nets (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'LEAD_1',
#    'IndicatorName': 'Percentage of the children under 15 years with blood lead levels above 5ug/dl',
#    'Language': 'EN'},
#   {'IndicatorCode': 'IR_PYRETHROID_EXTENT',
#    'IndicatorName': 'Percentage of sites for which pyrethroid resistance was reported',
#    'Language': 'EN'},
#   {'IndicatorCode': 'LEAD_10',
#    'IndicatorName': "Lead attributable DALYs per 100'000 children under 5 years",
#    'Language': 'EN'},
#   {'IndicatorCode': 'LEAD_2',
#    'IndicatorName': 'Percentage of the children under 15 years with blood lead levels above 10ug/dl',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RADON_Q701',
#    'IndicatorName': 'Mandatory preventive measures (new buildings)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Rev_curr',
#    'IndicatorName': 'Annual tax revenues - currency',
#    'Language': 'EN'},
#   {'IndicatorCode': 'LEAD_7',
#    'IndicatorName': "Lead attributable deaths per 100'000 capita",
#    'Language': 'EN'},
#   {'IndicatorCode': 'RADON_Q601',
#    'IndicatorName': 'Existence of official protocols for radon measurements',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RADON_Q604',
#    'IndicatorName': 'Authorization/accreditation required for official radon measurement providers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RADON_Q803',
#    'IndicatorName': 'Inclusion of radon in national cancer control strategy',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RADON_Q502',
#    'IndicatorName': 'Existence of national reference level for buildings with high public occupancy',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RADON_Q602',
#    'IndicatorName': 'Radon concentration measurements for new buildings',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RADON_Q703',
#    'IndicatorName': 'Financial support provided for mitigation (existing dwellings)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RADON_Q704',
#    'IndicatorName': 'Authorization/accreditation required for prevention/mitigation service providers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RADON_Q705',
#    'IndicatorName': 'Official standards/guidelines for prevention/mitigation',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RADON_Q706',
#    'IndicatorName': 'Existence of training/education on prevention/mitigation',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RADON_Q802',
#    'IndicatorName': 'Inclusion of radon measurements in property transactions',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Rev_govt_total',
#    'IndicatorName': 'Annual tax revenues - total revenues',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RS_1845',
#    'IndicatorName': 'Population',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RS_196',
#    'IndicatorName': 'Estimated number of road traffic deaths',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RS_208',
#    'IndicatorName': 'Attribution of road traffic deaths to alcohol (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RS_214',
#    'IndicatorName': 'Existence of national speed limits',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RS_217',
#    'IndicatorName': 'Maximum speed limits',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Rev_imp_other',
#    'IndicatorName': 'Annual tax revenues - import duties and all other taxes (excluding corporate taxes on tobacco companies)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Rev_type',
#    'IndicatorName': 'Annual tax revenues - tobacco products included',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RHR_IPV',
#    'IndicatorName': 'Intimate partner violence prevalence among ever partnered women (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RHR_NPSV',
#    'IndicatorName': 'Non-partner sexual violence prevalence (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'ROTAC',
#    'IndicatorName': 'Rotavirus vaccines completed dose (RotaC) immunization coverage among 1-year-olds (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RS_194',
#    'IndicatorName': 'Number of registered vehicles',
#    'Language': 'EN'},
#   {'IndicatorCode': 'RS_198',
#    'IndicatorName': 'Estimated road traffic death rate (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'P4_govt',
#    'IndicatorName': 'National smoking ban in GOVERNMENT FACILITIES',
#    'Language': 'EN'},
#   {'IndicatorCode': 'P5_compliance',
#    'IndicatorName': 'Compliance of ban on smoking in INDOOR OFFICES',
#    'Language': 'EN'},
#   {'IndicatorCode': 'P9_all_other',
#    'IndicatorName': 'National smoking ban in ALL OTHER INDOOR PUBLIC PLACES',
#    'Language': 'EN'},
#   {'IndicatorCode': 'PC_sfe_compliance',
#    'IndicatorName': 'Compliance with regulations on smoke-free environments (national legislation)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'pncall3',
#    'IndicatorName': 'Postnatal care visit within two days of birth (in the three years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'pnchome',
#    'IndicatorName': 'Postnatal care visit within two days of birth - born outside a health facility (in the x years preceding the survey) (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'poliov',
#    'IndicatorName': 'Polio immunization coverage among one-year-olds (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q10x2_HOSUE',
#    'IndicatorName': 'Availability of atleast one housing adjustment for people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q11x2x1',
#    'IndicatorName': 'Dementia nongovernmental organization equipped with office',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2_2',
#    'IndicatorName': 'Existence of psycho-social supports for dementia carers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2_3',
#    'IndicatorName': 'Existence of respite care for dementia carers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2_4',
#    'IndicatorName': 'Existence of information on legal rights for dementia carers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_1PUB',
#    'IndicatorName': 'Majority provider of dementia carer training and education (Public sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_2NGO',
#    'IndicatorName': 'Majority provider of psycho-social supports for dementia carers (NGO)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'R_admin_duty_free_limited',
#    'IndicatorName': 'Tax administration: Bans or limits on duty free imports by travellers',
#    'Language': 'EN'},
#   {'IndicatorCode': 'R_afford_price_dispersion',
#    'IndicatorName': 'Affordability: Price dispersion: share of cheapest brand price in premium brand price (the higher the % the smaller the gap)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'R_afford_tax_auto_adjust',
#    'IndicatorName': 'Affordability: Specific tax component automatically adjusted for inflation (or other)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_5',
#    'IndicatorName': 'Accessibility of financial benefits/social protection for dementia carers [Capital/capital and main cities/capital, main cities, rural areas]',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q12x2x1x1_5PRV',
#    'IndicatorName': 'Majority provider of information on financial benefits/social protection for dementia carers (Private sector)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q14x1',
#    'IndicatorName': 'Availability of dementia-friendly initiatives that improve accessibility',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q14x2_2',
#    'IndicatorName': 'Existence of dementia-friendly initiative to improve accessibility of public transportation',
#    'Language': 'EN'},
#   {'IndicatorCode': 'R_Sp_excise_estimate',
#    'IndicatorName': 'Most sold brand of cigarettes - taxes as a % of price - specific excise',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_4',
#    'IndicatorName': 'Existence of dementia training for legal professionals',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_6',
#    'IndicatorName': 'Existence of dementia training for school children',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x1x1_other',
#    'IndicatorName': 'Data sources used to routinely monitor people with dementia (Other)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x1x2_1',
#    'IndicatorName': 'Electronic availability of data sources used to routinely monitor people with dementia',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x2_1',
#    'IndicatorName': 'Availability of routine hospital admissions records for people with dementia for monitoring purposes',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x2_2',
#    'IndicatorName': 'Availability of routine outpatient visit records for people with dementia for monitoring purposes',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q16x2_4',
#    'IndicatorName': 'Availability of routine pharmaceutical records for people with dementia for monitoring purposes',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q17x2',
#    'IndicatorName': 'Dementia integrated into other national research plan/programme',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q17x2x1_4',
#    'IndicatorName': 'Identification of other research plans in which dementia is integrated (NCD)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'LEAD_8',
#    'IndicatorName': "Lead attributable DALYs per 100'000 capita",
#    'Language': 'EN'},
#   {'IndicatorCode': 'LEPTO_DALY',
#    'IndicatorName': 'Disability-adjusted life years (DALYs) due to leptospirosis',
#    'Language': 'EN'},
#   {'IndicatorCode': 'LEPTO_DALY100K',
#    'IndicatorName': 'Disability-adjusted life years (DALYs) (per 100 000 population) due to leptospirosis',
#    'Language': 'EN'},
#   {'IndicatorCode': 'LEPTO_MORBIDITY',
#    'IndicatorName': 'Estimated leptospirosis incidence (per 100 000 population)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'LIFE_0000000032',
#    'IndicatorName': 'ndx - number of people dying between ages x and x+n',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Rev_excise',
#    'IndicatorName': 'Annual tax revenues - total excise (specific and ad valorem)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'Rev_year',
#    'IndicatorName': 'Annual tax revenues - year',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q14x2_6',
#    'IndicatorName': 'Existence of dementia-friendly initiative supporting social opportunities',
#    'Language': 'EN'},
#   {'IndicatorCode': 'M_def_2_prev_adult',
#    'IndicatorName': 'Adult indicator 2 rate',
#    'Language': 'EN'},
#   {'IndicatorCode': 'M_Est_cig_curr_crude',
#    'IndicatorName': 'Current cigarette smoking, crude adjusted',
#    'Language': 'EN'},
#   {'IndicatorCode': 'M_Est_cig_daily',
#    'IndicatorName': 'Estimate of daily cigarette smoking prevalence (%)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q18x2x3_1',
#    'IndicatorName': 'Total expenditure on dementia basic research (local currency, self-report)',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_2',
#    'IndicatorName': 'Existence of dementia training for police and fire services',
#    'Language': 'EN'},
#   {'IndicatorCode': 'GDO_q15x2_3',
#    'IndicatorName': 'Existence of dementia training for first responders',
#    'Language': 'EN'},
#   ...]}

# %%
response.keys()
# Out:
# dict_keys(['@odata.context', 'value'])
