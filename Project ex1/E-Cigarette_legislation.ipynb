# %%
# Dependencies
import pandas as pd
from pathlib import Path

# %%
# Store filepath in a variable
file = Path("Resources /CDC_STATE_System_E-Cigarette_Legislation_-_Youth_Access.csv")

# %%
# Read our data file with the Pandas library
e_cigarette_legislation_df = pd.read_csv(file)
e_cigarette_legislation_df
# Out:
# /var/folders/6y/q85ngpfd649cw8503ftfc2tr0000gn/T/ipykernel_64337/1622084942.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   e_cigarette_legislation_df = pd.read_csv(file)
#         YEAR  Quarter LocationAbbr    LocationDesc  \
# 0       2021        3           RI    Rhode Island
# 1       2022        1           CO        Colorado
# 2       2021        4           RI    Rhode Island
# 3       2021        1           AR        Arkansas
# 4       2020        4           AR        Arkansas
# ...      ...      ...          ...             ...
# 146155  2024        1           PA    Pennsylvania
# 146156  2024        1           IL        Illinois
# 146157  2024        1           NC  North Carolina
# 146158  2024        1           MO        Missouri
# 146159  2024        1           CA      California
#
#                                        TopicDesc  \
# 0       Legislation - E-Cigarette - Youth Access
# ...

# %%
e_cigarette_legislation_df.columns
# Out:
# Index(['YEAR', 'Quarter', 'LocationAbbr', 'LocationDesc', 'TopicDesc',
#        'MeasureDesc', 'DataSource', 'ProvisionGroupDesc', 'ProvisionDesc',
#        'ProvisionValue', 'Citation', 'ProvisionAltValue', 'DataType',
#        'Comments', 'Enacted_Date', 'Effective_Date', 'GeoLocation',
#        'DisplayOrder', 'TopicTypeId', 'TopicId', 'MeasureId',
#        'ProvisionGroupID', 'ProvisionID'],
#       dtype='object')

# %%
# Collect a list of all the unique values in "Utility"
e_cigarette_legislation_df["ProvisionGroupDesc"].unique()
# Out:
# array(['Restrictions', 'Penalties', 'Enforcement'], dtype=object)
